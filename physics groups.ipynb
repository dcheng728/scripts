# %% [markdown]
# # Definition of the generators

# %%
xs = [matrix([[1],[0],[0]]),matrix([[0],[1],[0]]),matrix([[0],[0],[1]])]

# %%
sigmas = [matrix([[0,1],[1,0]]),matrix([[0,-i],[i,0]]),matrix([[1,0],[0,-1]])]

# %%
def cmtr(A,B):
    return A*B - B*A

# %% [markdown]
# # Rotation Generators
# In order to construct 4-vectors out of the Lorentz reprensentations, we must have $D^{(\frac{1}{2},\frac{1}{2})} \sim D^{(\frac{1}{2},0)} \otimes D^{(0,\frac{1}{2})}$, which is generated by $J^{(s_+)},J^{(s_-)}$. The corresponding $L$s will be the same for both $J^{(s_+)},J^{(s_-)}$, but the $M$s will be different.

# %%
Ls =   [1/2 *matrix([[0,1],[1,0]]),1/2 * matrix([[0,-i],[i,0]]),1/2 * matrix([[1,0],[0,-1]])]

# %% [markdown]
# ## Boost Generators
# As we said earlier, this will depend on $J^{(s_+)}$ or $J^{(s_-)}$

# %% [markdown]
# For $J^{(s_+)}$

# %%
Msp =   [i/2 *matrix([[0,1],[1,0]]),i/2 * matrix([[0,-i],[i,0]]),i/2 * matrix([[1,0],[0,-1]])]

# %% [markdown]
# For $J^{(s_-)}$

# %%
Msm =   [-i/2 *matrix([[0,1],[1,0]]),-i/2 * matrix([[0,-i],[i,0]]),-i/2 * matrix([[1,0],[0,-1]])]

# %%
cmtr(Msp[0],Msp[1])
# Out:
# [-1/2*I      0]
# [     0  1/2*I]

# %%
Msp
# Out:
# [
# [    0 1/2*I]  [   0  1/2]  [ 1/2*I      0]
# [1/2*I     0], [-1/2    0], [     0 -1/2*I]
# ]
